# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import  matplotlib.pyplot as plt

# %%
df= pd.read_csv("DataSet\DataSet_LinearRegression\StudentsPerformance.csv")

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
X=df[["reading score",
"writing score",
"parental level of education",
"lunch",
"test preparation course"]]
y=df["math score"]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   reading score                1000 non-null   int64
#  1   writing score                1000 non-null   int64
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 39.2+ KB

# %%
X["reading score"].plot(kind="hist")
plt.show()

# %%
X["writing score"].plot(kind="hist")
plt.show()

# %%
X["lunch"].unique()
# Out:
# array(['standard', 'free/reduced'], dtype=object)

# %%
X["parental level of education"].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
X["test preparation course"].unique()
# Out:
# array(['none', 'completed'], dtype=object)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder,LabelEncoder,StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
X=pd.get_dummies(X,columns=["parental level of education","lunch","test preparation course"],drop_first=True)

# %%
X=X.astype(int)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=42)

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
print("Mean Squared Error:",mean_squared_error(y_test,y_pred))
# Out:
# Mean Squared Error: 74.97283565705163

# %%
print("R2 Score:",r2_score(y_test,y_pred))
# Out:
# R2 Score: 0.7497798577999295
